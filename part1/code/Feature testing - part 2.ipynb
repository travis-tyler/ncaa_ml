# %% [markdown]
# ## Feature testing - Model loss

# %%
# libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# read in data
all_stats_df = pd.DataFrame(pd.read_csv('../resources/transformed_data/all_stats.csv'))
all_stats_df = all_stats_df.drop(columns=['WTeamID'])

# drop all NaNs
all_stats_df = all_stats_df.dropna(how='any')

all_stats_df.head()
# Out:
#        Season  DayNum  Team1  Team2  Tourney  WLoc  ScoreDiff  Team1Seed  \
# 74048    2003      10   1104   1328        0     0          6         10
# 74049    2003      10   1272   1393        0     0          7          7
# 74050    2003      11   1266   1437        0     0         12          3
# 74051    2003      11   1296   1457        0     0          6         30
# 74052    2003      11   1208   1400        0     0          6         30
#
#        Team2Seed  Team1FirstYear  ...  AvgStl_Team1  AvgStl_Team2  \
# 74048          1            1985  ...      6.607143      6.933333
# 74049          3            1985  ...      7.379310      8.310345
# 74050         30            1985  ...      6.000000      7.500000
# 74051         30            1985  ...      7.612903      7.607143
# 74052          1            1985  ...      7.629630      6.392857
#
#        AvgBlk_Team1  AvgBlk_Team2  AvgPF_Team1  AvgPF_Team2  FG%_Team1  \
# 74048      3.785714      3.766667    18.035714    18.600000   0.420362
# 74049      5.068966      7.275862    18.758621    16.586207   0.437931
# 74050      3.642857      3.400000    18.642857    20.900000   0.483810
# 74051      3.612903      5.392857    19.806452    19.642857   0.458967
# 74052      4.370370      3.857143    17.185185    20.357143   0.464135
#
#        FG%_Team2  FG3%_Team1  FG3%_Team2
# 74048   0.446934    0.320144    0.393673
# 74049   0.470067    0.348797    0.330435
# 74050   0.420429    0.379391    0.349040
# 74051   0.432107    0.383104    0.351687
# 74052   0.448513    0.380252    0.348936
#
# [5 rows x 56 columns]

# %%
# starter DF to reset to each iteration
starter_df = all_stats_df[['Season', 
                           'Team1', 'Team2',
                           'WLoc','WTeam',
                           'Tourney',
                           'Team1RankMean','Team2RankMean',
                           'WinCount_Team1', 'WinCount_Team2', 
#                            'Team1Seed', 'Team2Seed', 
#                            'Win%_Team1','Win%_Team2', 
#                            'LoseCount_Team1', 'LoseCount_Team2',
#                            'FG3%_Team1', 'FG3%_Team2',
#                            'AvgFGM_Team1', 'AvgFGM_Team2',
                           'GameCount_Team1', 'GameCount_Team2',
                          ]]
starter_df
# Out:
#         Season  Team1  Team2  WLoc  WTeam  Tourney  Team1RankMean  \
# 74048     2003   1104   1328     0      1        0      27.655502
# 74049     2003   1272   1393     0      1        0      42.000000
# 74050     2003   1266   1437     0      1        0      18.967442
# 74051     2003   1296   1457     0      1        0     147.512500
# 74052     2003   1208   1400     0      0        0      19.261283
# ...        ...    ...    ...   ...    ...      ...            ...
# 168791    2014   1163   1277     0      1        1      26.517978
# 168792    2014   1246   1276     0      1        1      20.905134
# 168793    2014   1163   1196     0      1        1      26.517978
# 168794    2014   1246   1458     0      1        1      20.905134
# 168795    2014   1163   1246     0      1        1      26.517978
#
#         Team2RankMean  WinCount_Team1  WinCount_Team2  GameCount_Team1  \
# 74048       15.730233            17.0            24.0             28.0
# 74049       25.596154            23.0            24.0             29.0
# 74050       60.385000            23.0            15.0             28.0
# 74051      209.452500            17.0            18.0             31.0
# 74052        9.416279            19.0            22.0             27.0
# ...               ...             ...             ...              ...
# 168791      10.352550            26.0            26.0             34.0
# 168792      22.406109            24.0            25.0             34.0
# 168793      11.246120            26.0            32.0             34.0
# 168794       9.019978            24.0            26.0             34.0
# 168795      20.905134            26.0            24.0             34.0
#
#         GameCount_Team2
# 74048              30.0
# 74049              29.0
# 74050              30.0
# 74051              28.0
# 74052              28.0
# ...                 ...
# 168791             34.0
# 168792             33.0
# 168793             34.0
# 168794             33.0
# 168795             34.0
#
# [93472 rows x 12 columns]

# %%
# list of columns to iterate through
other_cols = ['Team1FirstYear', 'Team2FirstYear',
             'Team1Seed', 'Team2Seed',
#              'Team1RankMean', 'Team2RankMean', 
#              'WinCount_Team1', 'WinCount_Team2', 
#              'GameCount_Team1', 'GameCount_Team2', 
             'AvgScore_Team1', 'AvgScore_Team2',                              
             'Win%_Team1','Win%_Team2', 
             'LoseCount_Team1', 'LoseCount_Team2',
             'AvgFGM_Team1',  'AvgFGM_Team2', 
             'AvgFGA_Team1', 'AvgFGA_Team2', 
             'AvgFGM3_Team1', 'AvgFGM3_Team2', 
             'AvgFGA3_Team1', 'AvgFGA3_Team2', 
             'AvgOR_Team1', 'AvgOR_Team2', 
             'AvgDR_Team1', 'AvgDR_Team2', 
             'FG%_Team1', 'FG%_Team2', 
             'FG3%_Team1', 'FG3%_Team2'
             ]

# %% [markdown]
# ## Build model pipeline

# %%
# One hot encoder and scaler for pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector

ct = make_column_transformer(
    (StandardScaler(), make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(handle_unknown='ignore'), make_column_selector(dtype_include=object))
)

# %%
# build pipeline
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, LeaveOneOut
from sklearn import metrics

mlc = MLPClassifier(alpha=0.001, hidden_layer_sizes=(168,), 
              random_state=1, solver='sgd',
              nesterovs_momentum=True)

pipe = make_pipeline(ct, mlc)

# %% [markdown]
# ## Initial fit

# %%
# first fit

# select features and target
features_df = starter_df.copy()
target = features_df.pop('WTeam')
selected_features = features_df

X_train, X_test, y_train, y_test = train_test_split(selected_features, 
                                                    target, stratify=target, 
                                                    random_state=42)

pipe.fit(X_train, y_train)

preds = pipe.predict(X_test)
loss_score = metrics.log_loss(y_test, preds)

print('\n-------------------')
print(f'Log loss: {loss_score}')
print('---------------------')
print(metrics.confusion_matrix(y_test,preds))
print('\n-------------------')
print(metrics.classification_report(y_test,preds))
print('-------------------\n')
# Out:
# -------------------
# Log loss: 8.484030613383828
# ---------------------
# [[9205 2815]
#  [2925 8423]]
#
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.75     23368
#    macro avg       0.75      0.75      0.75     23368
# weighted avg       0.75      0.75      0.75     23368
#
# -------------------

# %% [markdown]
# log loss 1: 8.520980999224033
#
# log loss 2: 8.39830485868785
#
# log loss 3: 8.367263816334052
#
# Current log loss: Log loss: 8.314055601531692

# %% [markdown]
# ## Team1 and Team2 stat fits

# %%
# feature iteration
effective_features = {}

for col in other_cols[::2]:
    iteration_df = starter_df.copy()
    team1_stat = col
    team2_stat = other_cols[other_cols.index(col)+1]
    print(f'{team1_stat} - {team2_stat}')
    iteration_df[team1_stat] = all_stats_df[team1_stat]
    iteration_df[team2_stat] = all_stats_df[team2_stat]

    # select features and target
    target = iteration_df.pop('WTeam')
    selected_features = iteration_df

    X_train, X_test, y_train, y_test = train_test_split(selected_features, 
                                                        target, stratify=target, 
                                                        random_state=42)

    pipe.fit(X_train, y_train)

    preds = pipe.predict(X_test)
    new_loss_score = metrics.log_loss(y_test, preds)

    print(f'Log loss: {new_loss_score}')
    print('---------------------')
    print(metrics.confusion_matrix(y_test,preds))
    print('-------------------')
    print(metrics.classification_report(y_test,preds))
    print('-------------------\n\n')
    
    # add effective features to dict
    if new_loss_score < loss_score:
#         loss_score = new_loss_score
        effective_features[team1_stat] = new_loss_score - loss_score
# Out:
# Team1FirstYear - Team2FirstYear
# Log loss: 15.964368658544355
# ---------------------
# [[9465 2555]
#  [8246 3102]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.53      0.79      0.64     12020
#            1       0.55      0.27      0.36     11348
#
#     accuracy                           0.54     23368
#    macro avg       0.54      0.53      0.50     23368
# weighted avg       0.54      0.54      0.50     23368
#
# -------------------
#
#
# Team1Seed - Team2Seed
# Log loss: 13.466461374104854
# ---------------------
# [[10172  1848]
#  [ 7263  4085]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.58      0.85      0.69     12020
#            1       0.69      0.36      0.47     11348
#
#     accuracy                           0.61     23368
#    macro avg       0.64      0.60      0.58     23368
# weighted avg       0.63      0.61      0.58     23368
#
# -------------------
#
#
# Team1RankMean - Team2RankMean
# Log loss: 8.606709080718424
# ---------------------
# [[9165 2855]
#  [2968 8380]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76     12020
#            1       0.75      0.74      0.74     11348
#
#     accuracy                           0.75     23368
#    macro avg       0.75      0.75      0.75     23368
# weighted avg       0.75      0.75      0.75     23368
#
# -------------------
#
#
# WinCount_Team1 - WinCount_Team2
# Log loss: 9.03534284997138
# ---------------------
# [[9079 2941]
#  [3172 8176]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75     12020
#            1       0.74      0.72      0.73     11348
#
#     accuracy                           0.74     23368
#    macro avg       0.74      0.74      0.74     23368
# weighted avg       0.74      0.74      0.74     23368
#
# -------------------
#
#
# GameCount_Team1 - GameCount_Team2
# Log loss: 12.882708313535979
# ---------------------
# [[8077 3943]
#  [4773 6575]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65     12020
#            1       0.63      0.58      0.60     11348
#
#     accuracy                           0.63     23368
#    macro avg       0.63      0.63      0.63     23368
# weighted avg       0.63      0.63      0.63     23368
#
# -------------------
#
#
# AvgScore_Team1 - AvgScore_Team2
# Log loss: 12.369832472827836
# ---------------------
# [[7986 4034]
#  [4335 7013]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.66     12020
#            1       0.63      0.62      0.63     11348
#
#     accuracy                           0.64     23368
#    macro avg       0.64      0.64      0.64     23368
# weighted avg       0.64      0.64      0.64     23368
#
# -------------------
#
#
# Win%_Team1 - Win%_Team2
# Log loss: 9.092988906493385
# ---------------------
# [[9003 3017]
#  [3135 8213]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75     12020
#            1       0.73      0.72      0.73     11348
#
#     accuracy                           0.74     23368
#    macro avg       0.74      0.74      0.74     23368
# weighted avg       0.74      0.74      0.74     23368
#
# -------------------
#
#
# LoseCount_Team1 - LoseCount_Team2
# Log loss: 9.432943789100223
# ---------------------
# [[8819 3201]
#  [3181 8167]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73     12020
#            1       0.72      0.72      0.72     11348
#
#     accuracy                           0.73     23368
#    macro avg       0.73      0.73      0.73     23368
# weighted avg       0.73      0.73      0.73     23368
#
# -------------------
#
#
# AvgFGM_Team1 - AvgFGM_Team2
# Log loss: 12.73491019193753
# ---------------------
# [[7913 4107]
#  [4509 6839]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.66      0.65     12020
#            1       0.62      0.60      0.61     11348
#
#     accuracy                           0.63     23368
#    macro avg       0.63      0.63      0.63     23368
# weighted avg       0.63      0.63      0.63     23368
#
# -------------------
#
#
# AvgFGA_Team1 - AvgFGA_Team2
# Log loss: 16.03683522566781
# ---------------------
# [[8216 3804]
#  [7046 4302]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.68      0.60     12020
#            1       0.53      0.38      0.44     11348
#
#     accuracy                           0.54     23368
#    macro avg       0.53      0.53      0.52     23368
# weighted avg       0.53      0.54      0.52     23368
#
# -------------------
#
#
# AvgFGM3_Team1 - AvgFGM3_Team2
# Log loss: 15.339220150497033
# ---------------------
# [[7674 4346]
#  [6032 5316]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.56      0.64      0.60     12020
#            1       0.55      0.47      0.51     11348
#
#     accuracy                           0.56     23368
#    macro avg       0.56      0.55      0.55     23368
# weighted avg       0.56      0.56      0.55     23368
#
# -------------------
#
#
# AvgFGA3_Team1 - AvgFGA3_Team2
# Log loss: 16.567423835775013
# ---------------------
# [[8999 3021]
#  [8188 3160]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.52      0.75      0.62     12020
#            1       0.51      0.28      0.36     11348
#
#     accuracy                           0.52     23368
#    macro avg       0.52      0.51      0.49     23368
# weighted avg       0.52      0.52      0.49     23368
#
# -------------------
#
#
# AvgOR_Team1 - AvgOR_Team2
# Log loss: 16.070849177758234
# ---------------------
# [[7658 4362]
#  [6511 4837]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.64      0.58     12020
#            1       0.53      0.43      0.47     11348
#
#     accuracy                           0.53     23368
#    macro avg       0.53      0.53      0.53     23368
# weighted avg       0.53      0.53      0.53     23368
#
# -------------------
#
#
# AvgDR_Team1 - AvgDR_Team2
# Log loss: 13.785799868263961
# ---------------------
# [[7763 4257]
#  [5070 6278]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.60      0.65      0.62     12020
#            1       0.60      0.55      0.57     11348
#
#     accuracy                           0.60     23368
#    macro avg       0.60      0.60      0.60     23368
# weighted avg       0.60      0.60      0.60     23368
#
# -------------------
#
#
# FG%_Team1 - FG%_Team2
# Log loss: 11.958933166947354
# ---------------------
# [[8130 3890]
#  [4201 7147]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67     12020
#            1       0.65      0.63      0.64     11348
#
#     accuracy                           0.65     23368
#    macro avg       0.65      0.65      0.65     23368
# weighted avg       0.65      0.65      0.65     23368
#
# -------------------
#
#
# FG3%_Team1 - FG3%_Team2
# Log loss: 13.754763205765997
# ---------------------
# [[7701 4319]
#  [4987 6361]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62     12020
#            1       0.60      0.56      0.58     11348
#
#     accuracy                           0.60     23368
#    macro avg       0.60      0.60      0.60     23368
# weighted avg       0.60      0.60      0.60     23368
#
# -------------------

# %%
effective_features
# Out:
# {'Team1FirstYear': -0.9178712094867549,
#  'Team1Seed': -3.415778493926256,
#  'Team1RankMean': -8.275530787312686,
#  'WinCount_Team1': -7.84689701805973,
#  'GameCount_Team1': -3.9995315544951318,
#  'AvgScore_Team1': -4.512407395203274,
#  'Win%_Team1': -7.789250961537725,
#  'LoseCount_Team1': -7.449296078930887,
#  'AvgFGM_Team1': -4.14732967609358,
#  'AvgFGA_Team1': -0.8454046423632988,
#  'AvgFGM3_Team1': -1.5430197175340776,
#  'AvgFGA3_Team1': -0.3148160322560969,
#  'AvgOR_Team1': -0.8113906902728765,
#  'AvgDR_Team1': -3.0964399997671492,
#  'FG%_Team1': -4.923306701083757,
#  'FG3%_Team1': -3.1274766622651136}

# %%
# return most effective loss-reducing feature
import operator
min(effective_features.items(), key=operator.itemgetter(1))[0]
# Out:
# 'Team1RankMean'

# %% [markdown]
# ## Stat difference fits

# %%
# feature iteration
effective_features = {}

for col in other_cols[::2]:
    iteration_df = starter_df.copy()
    team1_stat = col
    team2_stat = other_cols[other_cols.index(col)+1]
    print(f'{team1_stat}- {team2_stat}')
    iteration_df['TestColumn']=\
        all_stats_df[team1_stat] - all_stats_df[team2_stat]

    # select features and target
    target = iteration_df.pop('WTeam')
    selected_features = iteration_df

    X_train, X_test, y_train, y_test = train_test_split(selected_features, 
                                                        target, stratify=target, 
                                                        random_state=42)

    pipe.fit(X_train, y_train)

    preds = pipe.predict(X_test)
    new_loss_score = metrics.log_loss(y_test, preds)

    print(f'Log loss: {new_loss_score}')
    print('---------------------')
    print(metrics.confusion_matrix(y_test,preds))
    print('-------------------')
    print(metrics.classification_report(y_test,preds))
    print('-------------------\n\n')
    
    # add effective features to dict
    if new_loss_score < loss_score:
        effective_features[team1_stat] = new_loss_score - loss_score
        loss_score = new_loss_score
# Out:
# Team1FirstYear- Team2FirstYear
# Log loss: 8.373176170971345
# ---------------------
# [[9253 2767]
#  [2898 8450]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# Team1Seed- Team2Seed
# Log loss: 8.385000606504939
# ---------------------
# [[9249 2771]
#  [2902 8446]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgScore_Team1- AvgScore_Team2
# Log loss: 8.362829293723907
# ---------------------
# [[9271 2749]
#  [2909 8439]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# Win%_Team1- Win%_Team2
# Log loss: 8.401258298596602
# ---------------------
# [[9270 2750]
#  [2934 8414]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# LoseCount_Team1- LoseCount_Team2
# Log loss: 8.429342000232547
# ---------------------
# [[9241 2779]
#  [2924 8424]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgFGM_Team1- AvgFGM_Team2
# Log loss: 8.390912242572133
# ---------------------
# [[9264 2756]
#  [2921 8427]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgFGA_Team1- AvgFGA_Team2
# Log loss: 8.392390793169374
# ---------------------
# [[9249 2771]
#  [2907 8441]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgFGM3_Team1- AvgFGM3_Team2
# Log loss: 8.371697688809348
# ---------------------
# [[9266 2754]
#  [2910 8438]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgFGA3_Team1- AvgFGA3_Team2
# Log loss: 8.407171645544977
# ---------------------
# [[9235 2785]
#  [2903 8445]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgOR_Team1- AvgOR_Team2
# Log loss: 8.41160538114978
# ---------------------
# [[9246 2774]
#  [2917 8431]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# AvgDR_Team1- AvgDR_Team2
# Log loss: 8.385000195893454
# ---------------------
# [[9261 2759]
#  [2914 8434]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# FG%_Team1- FG%_Team2
# Log loss: 8.383521645296211
# ---------------------
# [[9276 2744]
#  [2928 8420]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------
#
#
# FG3%_Team1- FG3%_Team2
# Log loss: 8.393868248802658
# ---------------------
# [[9266 2754]
#  [2925 8423]]
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     12020
#            1       0.75      0.74      0.75     11348
#
#     accuracy                           0.76     23368
#    macro avg       0.76      0.76      0.76     23368
# weighted avg       0.76      0.76      0.76     23368
#
# -------------------

# %%
effective_features
# Out:
# {}

# %%
# return most effective loss-reducing feature
import operator
min(effective_features.items(), key=operator.itemgetter(1))[0]
# Out:
# 'GameCount_Team1'
